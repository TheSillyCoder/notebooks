# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
data_file = open('data_planck.txt', 'r')
rows = data_file.readlines()
data_init = [row.split('\t') for row in rows]
data = [[],[]]
for i in range(len(data_init)):
    data[0].append(eval(data_init[i][0].strip()))
    data[1].append(eval(data_init[i][1].strip()))

# %%
x = np.array(data[0])
y = np.array(data[1])

# %%
def f(x, m, c):
    return (m * x) + c
popt, pcov = curve_fit(f, x, y)

# %%
x_sample = np.linspace(4.5, 6.8, 50)
y_sample = f(x_sample, popt[0], popt[1])

# %%
x_sample
# Out:
# array([4.5       , 4.54693878, 4.59387755, 4.64081633, 4.6877551 ,
#        4.73469388, 4.78163265, 4.82857143, 4.8755102 , 4.92244898,
#        4.96938776, 5.01632653, 5.06326531, 5.11020408, 5.15714286,
#        5.20408163, 5.25102041, 5.29795918, 5.34489796, 5.39183673,
#        5.43877551, 5.48571429, 5.53265306, 5.57959184, 5.62653061,
#        5.67346939, 5.72040816, 5.76734694, 5.81428571, 5.86122449,
#        5.90816327, 5.95510204, 6.00204082, 6.04897959, 6.09591837,
#        6.14285714, 6.18979592, 6.23673469, 6.28367347, 6.33061224,
#        6.37755102, 6.4244898 , 6.47142857, 6.51836735, 6.56530612,
#        6.6122449 , 6.65918367, 6.70612245, 6.75306122, 6.8       ])

# %%
plt.style.use('default')
# plt.figure(figsize=(16, 12))
plt.plot(x, y, 'ko', label="Coil 1", markersize=8)
# plt.plot(x, Super, 'g^-', label="Added readings of Coil1 and Coil 2", markersize=8)
plt.plot(x_sample, y_sample, 'b-', markersize=8)
plt.grid()
plt.xlabel("Frequency of incident light [sec^-1 x 10^14]", fontsize=15)
plt.ylabel("Stoppping Poential [V]", fontsize=15)
# plt.ylim(top=15.5)
# plt.legend(loc='upper right', fontsize=15)
plt.title("Determination of Planck's constant using Photoelectric Effect", fontsize=20)
plt.savefig("photoelec-plot.pdf")

# %%
# Out:
# array([ 0.41302759, -1.60025875])
